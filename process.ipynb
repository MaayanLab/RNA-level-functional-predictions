# %%
import h5py
import pandas as pd
import numpy as np
import json
# Out:
# /opt/apps/rhel7/Python-GPU-3.6.5/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
f = h5py.File("tcga.hdf5", "r+")

# %%
# transpose to get 60000x60000 matrix
# ex_matrix = np.transpose(f['ex_matrix'])
data = f['data']
meta = f['meta']
genes = f['meta']['genes']
eids = f['meta']['ensembl_id']
gene_exp = data['processed_expression']

# %% [markdown]
# # Subcorrelation matrix

# %%
with open("biomart.json") as b:
    eid_to_type = json.load(b)
eid_to_type
# Out:
# {'ENSG00000210049': 'Mt_tRNA',
#  'ENSG00000211459': 'Mt_rRNA',
#  'ENSG00000210077': 'Mt_tRNA',
#  'ENSG00000210082': 'Mt_rRNA',
#  'ENSG00000209082': 'Mt_tRNA',
#  'ENSG00000198888': 'protein_coding',
#  'ENSG00000210100': 'Mt_tRNA',
#  'ENSG00000210107': 'Mt_tRNA',
#  'ENSG00000210112': 'Mt_tRNA',
#  'ENSG00000198763': 'protein_coding',
#  'ENSG00000210117': 'Mt_tRNA',
#  'ENSG00000210127': 'Mt_tRNA',
#  'ENSG00000210135': 'Mt_tRNA',
#  'ENSG00000210140': 'Mt_tRNA',
#  'ENSG00000210144': 'Mt_tRNA',
#  'ENSG00000198804': 'protein_coding',
#  'ENSG00000210151': 'Mt_tRNA',
#  'ENSG00000210154': 'Mt_tRNA',
#  'ENSG00000198712': 'protein_coding',
#  'ENSG00000210156': 'Mt_tRNA',
#  'ENSG00000228253': 'protein_coding',
#  'ENSG00000198899': 'protein_coding',
#  'ENSG00000198938': 'protein_coding',
#  'ENSG00000210164': 'Mt_tRNA',
#  'ENSG00000198840': 'protein_coding',
#  'ENSG00000210174': 'Mt_tRNA',
#  'ENSG00000212907': 'protein_coding',
#  'ENSG00000198886': 'protein_coding',
#  'ENSG00000210176': 'Mt_tRNA',
#  'ENSG00000210184': 'Mt_tRNA',
#  'ENSG00000210191': 'Mt_tRNA',
#  'ENSG00000198786': 'protein_coding',
#  'ENSG00000198695': 'protein_coding',
#  'ENSG00000210194': 'Mt_tRNA',
#  'ENSG00000198727': 'protein_coding',
#  'ENSG00000210195': 'Mt_tRNA',
#  'ENSG00000210196': 'Mt_tRNA',
#  'ENSG00000242065': 'misc_RNA',
#  'ENSG00000252951': 'rRNA_pseudogene',
#  'ENSG00000243352': 'misc_RNA',
#  'ENSG00000239553': 'misc_RNA',
#  'ENSG00000238590': 'snRNA',
#  'ENSG00000199567': 'misc_RNA',
#  'ENSG00000264352': 'misc_RNA',
#  'ENSG00000252443': 'snoRNA',
#  'ENSG00000243532': 'misc_RNA',
#  'ENSG00000212567': 'snoRNA',
#  'ENSG00000202314': 'snoRNA',
#  'ENSG00000199880': 'snRNA',
#  'ENSG00000221643': 'snoRNA',
#  'ENSG00000243115': 'misc_RNA',
#  'ENSG00000264910': 'misc_RNA',
#  'ENSG00000252852': 'snoRNA',
#  'ENSG00000252982': 'misc_RNA',
#  'ENSG00000206795': 'misc_RNA',
#  'ENSG00000202237': 'snRNA',
#  'ENSG00000252151': 'snRNA',
#  'ENSG00000222146': 'snRNA',
#  'ENSG00000201812': 'rRNA_pseudogene',
#  'ENSG00000222594': 'misc_RNA',
#  'ENSG00000206779': 'misc_RNA',
#  'ENSG00000273908': 'misc_RNA',
#  'ENSG00000201690': 'misc_RNA',
#  'ENSG00000199362': 'misc_RNA',
#  'ENSG00000200052': 'misc_RNA',
#  'ENSG00000277551': 'snRNA',
#  'ENSG00000265123': 'misc_RNA',
#  'ENSG00000276670': 'misc_RNA',
#  'ENSG00000264071': 'misc_RNA',
#  'ENSG00000252872': 'snRNA',
#  'ENSG00000251887': 'snRNA',
#  'ENSG00000222429': 'snRNA',
#  'ENSG00000252812': 'misc_RNA',
#  'ENSG00000207201': 'snRNA',
#  'ENSG00000240173': 'misc_RNA',
#  'ENSG00000253038': 'snRNA',
#  'ENSG00000206745': 'snRNA',
#  'ENSG00000252130': 'snRNA',
#  'ENSG00000223224': 'snoRNA',
#  'ENSG00000274197': 'snRNA',
#  'ENSG00000277563': 'misc_RNA',
#  'ENSG00000201185': 'rRNA_pseudogene',
#  'ENSG00000201035': 'rRNA_pseudogene',
#  'ENSG00000251998': 'snRNA',
#  'ENSG00000202532': 'snRNA',
#  'ENSG00000252634': 'misc_RNA',
#  'ENSG00000199878': 'misc_RNA',
#  'ENSG00000252325': 'snRNA',
#  'ENSG00000239964': 'misc_RNA',
#  'ENSG00000201901': 'misc_RNA',
#  'ENSG00000240823': 'misc_RNA',
#  'ENSG00000265116': 'snoRNA',
#  'ENSG00000280496': 'snoRNA',
#  'ENSG00000241964': 'misc_RNA',
#  'ENSG00000251730': 'snoRNA',
#  'ENSG00000252312': 'misc_RNA',
#  'ENSG00000278003': 'misc_RNA',
#  'ENSG00000222337': 'misc_RNA',
#  'ENSG00000206665': 'snRNA',
#  'ENSG00000283519': 'snRNA',
#  'ENSG00000276183': 'snRNA',
#  'ENSG00000212448': 'misc_RNA',
#  'ENSG00000241229': 'misc_RNA',
#  'ENSG00000251942': 'scaRNA',
#  'ENSG00000252305': 'snoRNA',
#  'ENSG00000201301': 'rRNA_pseudogene',
#  'ENSG00000222232': 'rRNA_pseudogene',
#  'ENSG00000252682': 'snoRNA',
#  'ENSG00000285674': 'rRNA_pseudogene',
#  'ENSG00000199601': 'snRNA',
#  'ENSG00000276696': 'misc_RNA',
#  'ENSG00000199473': 'snoRNA',
#  'ENSG00000252409': 'scaRNA',
#  'ENSG00000275696': 'misc_RNA',
#  'ENSG00000207256': 'snRNA',
#  'ENSG00000252341': 'misc_RNA',
#  'ENSG00000202069': 'snRNA',
#  'ENSG00000212340': 'snRNA',
#  'ENSG00000251986': 'misc_RNA',
#  'ENSG00000200168': 'rRNA_pseudogene',
#  'ENSG00000223174': 'misc_RNA',
#  'ENSG00000264036': 'misc_RNA',
#  'ENSG00000207261': 'snRNA',
#  'ENSG00000222592': 'snRNA',
#  'ENSG00000273541': 'misc_RNA',
#  'ENSG00000199591': 'misc_RNA',
#  'ENSG00000206760': 'snoRNA',
#  'ENSG00000202276': 'misc_RNA',
#  'ENSG00000252994': 'snRNA',
#  'ENSG00000241588': 'misc_RNA',
#  'ENSG00000199203': 'misc_RNA',
#  'ENSG00000252620': 'snRNA',
#  'ENSG00000206854': 'misc_RNA',
#  'ENSG00000252542': 'snoRNA',
#  'ENSG00000207393': 'snRNA',
#  'ENSG00000199735': 'snRNA',
#  'ENSG00000202095': 'snRNA',
#  'ENSG00000201746': 'snRNA',
#  'ENSG00000252185': 'snRNA',
#  'ENSG00000222704': 'misc_RNA',
#  'ENSG00000278104': 'misc_RNA',
#  'ENSG00000275930': 'misc_RNA',
#  'ENSG00000238426': 'misc_RNA',
#  'ENSG00000264767': 'misc_RNA',
#  'ENSG00000200913': 'snoRNA',
#  'ENSG00000278100': 'misc_RNA',
#  'ENSG00000206711': 'misc_RNA',
#  'ENSG00000200247': 'snRNA',
#  'ENSG00000251746': 'rRNA_pseudogene',
#  'ENSG00000251739': 'snRNA',
#  'ENSG00000222561': 'snRNA',
#  'ENSG00000241785': 'misc_RNA',
#  'ENSG00000278525': 'misc_RNA',
#  'ENSG00000200049': 'misc_RNA',
#  'ENSG00000222740': 'rRNA_pseudogene',
#  'ENSG00000241821': 'misc_RNA',
#  'ENSG00000199335': 'snRNA',
#  'ENSG00000200424': 'snRNA',
#  'ENSG00000277467': 'misc_RNA',
#  'ENSG00000222259': 'misc_RNA',
#  'ENSG00000276890': 'misc_RNA',
#  'ENSG00000212293': 'snoRNA',
#  'ENSG00000207442': 'snoRNA',
#  'ENSG00000278853': 'snRNA',
#  'ENSG00000222129': 'rRNA_pseudogene',
#  'ENSG00000272439': 'snRNA',
#  'ENSG00000221345': 'snoRNA',
#  'ENSG00000207235': 'misc_RNA',
#  'ENSG00000222924': 'snRNA',
#  'ENSG00000222489': 'snoRNA',
#  'ENSG00000242985': 'misc_RNA',
#  'ENSG00000273725': 'misc_RNA',
#  'ENSG00000243260': 'misc_RNA',
#  'ENSG00000200914': 'rRNA_pseudogene',
#  'ENSG00000206913': 'snoRNA',
#  'ENSG00000207338': 'snRNA',
#  'ENSG00000201778': 'misc_RNA',
#  'ENSG00000243870': 'misc_RNA',
#  'ENSG00000200786': 'rRNA_pseudogene',
#  'ENSG00000199315': 'rRNA_pseudogene',
#  'ENSG00000223175': 'snRNA',
#  'ENSG00000263467': 'snRNA',
#  'ENSG00000201727': 'rRNA_pseudogene',
#  'ENSG00000199744': 'snoRNA',
#  'ENSG00000264415': 'misc_RNA',
#  'ENSG00000264002': 'misc_RNA',
#  'ENSG00000252333': 'snRNA',
#  'ENSG00000252135': 'snRNA',
#  'ENSG00000201610': 'rRNA_pseudogene',
#  'ENSG00000201451': 'misc_RNA',
#  'ENSG00000207110': 'snRNA',
#  'ENSG00000199932': 'snRNA',
#  'ENSG00000201168': 'rRNA_pseudogene',
#  'ENSG00000222790': 'snRNA',
#  'ENSG00000222238': 'snRNA',
#  'ENSG00000239127': 'snoRNA',
#  'ENSG00000222795': 'snRNA',
#  'ENSG00000239545': 'misc_RNA',
#  'ENSG00000252828': 'rRNA_pseudogene',
#  'ENSG00000253098': 'snRNA',
#  'ENSG00000273612': 'misc_RNA',
#  'ENSG00000274186': 'misc_RNA',
#  'ENSG00000242113': 'misc_RNA',
#  'ENSG00000281000': 'snoRNA',
#  'ENSG00000276956': 'misc_RNA',
#  'ENSG00000202025': 'snRNA',
#  'ENSG00000206951': 'misc_RNA',
#  'ENSG00000206620': 'snoRNA',
#  'ENSG00000222987': 'misc_RNA',
#  'ENSG00000242079': 'misc_RNA',
#  'ENSG00000252172': 'snRNA',
#  'ENSG00000278700': 'misc_RNA',
#  'ENSG00000252783': 'snRNA',
#  'ENSG00000253051': 'snoRNA',
#  'ENSG00000253055': 'rRNA_pseudogene',
#  'ENSG00000281230': 'protein_coding',
#  'ENSG00000251711': 'snRNA',
#  'ENSG00000266794': 'misc_RNA',
#  'ENSG00000239030': 'snRNA',
#  'ENSG00000252446': 'snRNA',
#  'ENSG00000222303': 'snRNA',
#  'ENSG00000201247': 'snoRNA',
#  'ENSG00000200652': 'snoRNA',
#  'ENSG00000200807': 'snRNA',
#  'ENSG00000266634': 'miRNA',
#  'ENSG00000199444': 'misc_RNA',
#  'ENSG00000200208': 'misc_RNA',
#  'ENSG00000212371': 'snoRNA',
#  'ENSG00000238326': 'snoRNA',
#  'ENSG00000241188': 'misc_RNA',
#  'ENSG00000244671': 'misc_RNA',
#  'ENSG00000252145': 'snRNA',
#  'ENSG00000207750': 'miRNA',
#  'ENSG00000200283': 'misc_RNA',
#  'ENSG00000202252': 'snoRNA',
#  'ENSG00000231587': 'snoRNA',
#  'ENSG00000239080': 'snoRNA',
#  'ENSG00000207165': 'snoRNA',
#  'ENSG00000212157': 'snRNA',
#  'ENSG00000284485': 'miRNA',
#  'ENSG00000207382': 'misc_RNA',
#  'ENSG00000252091': 'snRNA',
#  'ENSG00000273566': 'misc_RNA',
#  'ENSG00000200792': 'snoRNA',
#  'ENSG00000265509': 'misc_RNA',
#  'ENSG00000202313': 'snRNA',
#  'ENSG00000276653': 'misc_RNA',
#  'ENSG00000207789': 'miRNA',
#  'ENSG00000207312': 'snRNA',
#  'ENSG00000278592': 'misc_RNA',
#  'ENSG00000206964': 'misc_RNA',
#  'ENSG00000209702': 'snoRNA',
#  'ENSG00000283159': 'miRNA',
#  'ENSG00000239607': 'misc_RNA',
#  'ENSG00000199012': 'miRNA',
#  'ENSG00000201987': 'misc_RNA',
#  'ENSG00000202336': 'snRNA',
#  'ENSG00000206769': 'snRNA',
#  'ENSG00000202159': 'snRNA',
#  'ENSG00000200295': 'snRNA',
#  'ENSG00000206959': 'misc_RNA',
#  'ENSG00000238721': 'snRNA',
#  'ENSG00000201489': 'misc_RNA',
#  'ENSG00000263413': 'miRNA',
#  'ENSG00000265319': 'misc_RNA',
#  'ENSG00000200305': 'misc_RNA',
#  'ENSG00000285912': 'rRNA_pseudogene',
#  'ENSG00000276891': 'misc_RNA',
#  'ENSG00000265093': 'misc_RNA',
#  'ENSG00000201968': 'rRNA_pseudogene',
#  'ENSG00000264484': 'misc_RNA',
#  'ENSG00000207341': 'rRNA_pseudogene',
#  'ENSG00000212238': 'rRNA_pseudogene',
#  'ENSG00000266039': 'miRNA',
#  'ENSG00000274350': 'misc_RNA',
#  'ENSG00000200152': 'snRNA',
#  'ENSG00000201231': 'snRNA',
#  'ENSG00000212517': 'snoRNA',
#  'ENSG00000200139': 'snRNA',
#  'ENSG00000252323': 'snRNA',
#  'ENSG00000276522': 'misc_RNA',
#  'ENSG00000284059': 'miRNA',
#  'ENSG00000251722': 'snRNA',
#  'ENSG00000223188': 'misc_RNA',
#  'ENSG00000281459': 'protein_coding',
#  'ENSG00000208003': 'miRNA',
#  'ENSG00000199677': 'misc_RNA',
#  'ENSG00000241997': 'misc_RNA',
#  'ENSG00000199474': 'snoRNA',
#  'ENSG00000275942': 'misc_RNA',
#  'ENSG00000243976': 'misc_RNA',
#  'ENSG00000251764': 'rRNA_pseudogene',
#  'ENSG00000207614': 'miRNA',
#  'ENSG00000275337': 'misc_RNA',
#  'ENSG00000277374': 'snRNA',
#  'ENSG00000222207': 'rRNA_pseudogene',
#  'ENSG00000275215': 'rRNA',
#  'ENSG00000264010': 'miRNA',
#  'ENSG00000200174': 'misc_RNA',
#  'ENSG00000251937': 'snRNA',
#  'ENSG00000199912': 'misc_RNA',
#  'ENSG00000201569': 'snoRNA',
#  'ENSG00000200757': 'snoRNA',
#  'ENSG00000252512': 'rRNA_pseudogene',
#  'ENSG00000265682': 'miRNA',
#  'ENSG00000251900': 'misc_RNA',
#  'ENSG00000199480': 'rRNA_pseudogene',
#  'ENSG00000281391': 'lncRNA',
#  'ENSG00000278524': 'miRNA',
#  'ENSG00000201711': 'snRNA',
#  'ENSG00000222895': 'snRNA',
#  'ENSG00000202099': 'snRNA',
#  'ENSG00000201923': 'rRNA_pseudogene',
#  'ENSG00000281540': 'protein_coding',
#  'ENSG00000252191': 'snRNA',
#  'ENSG00000216141': 'miRNA',
#  'ENSG00000201684': 'misc_RNA',
#  'ENSG00000252864': 'rRNA_pseudogene',
#  'ENSG00000281067': 'processed_pseudogene',
#  'ENSG00000275330': 'protein_coding',
#  'ENSG00000200875': 'snRNA',
#  'ENSG00000202304': 'snRNA',
#  'ENSG00000238804': 'snoRNA',
#  'ENSG00000275904': 'misc_RNA',
#  'ENSG00000216135': 'miRNA',
#  'ENSG00000252252': 'snRNA',
#  'ENSG00000200528': 'snRNA',
#  'ENSG00000201129': 'snoRNA',
#  'ENSG00000207449': 'snRNA',
#  'ENSG00000283745': 'miRNA',
#  'ENSG00000200057': 'misc_RNA',
#  'ENSG00000199733': 'rRNA_pseudogene',
#  'ENSG00000264389': 'snRNA',
#  'ENSG00000199962': 'misc_RNA',
#  'ENSG00000207507': 'snRNA',
#  'ENSG00000265942': 'misc_RNA',
#  'ENSG00000283956': 'miRNA',
#  'ENSG00000251825': 'misc_RNA',
#  'ENSG00000251877': 'snRNA',
#  'ENSG00000206885': 'snoRNA',
#  'ENSG00000207351': 'misc_RNA',
#  'ENSG00000221768': 'miRNA',
#  'ENSG00000265983': 'snRNA',
#  'ENSG00000251888': 'misc_RNA',
#  'ENSG00000278287': 'misc_RNA',
#  'ENSG00000273770': 'misc_RNA',
#  'ENSG00000199072': 'miRNA',
#  'ENSG00000262656': 'snRNA',
#  'ENSG00000263971': 'snRNA',
#  'ENSG00000244318': 'misc_RNA',
#  'ENSG00000222685': 'misc_RNA',
#  'ENSG00000223181': 'snRNA',
#  'ENSG00000199051': 'miRNA',
#  'ENSG00000207014': 'snoRNA',
#  'ENSG00000271922': 'snoRNA',
#  'ENSG00000276881': 'snRNA',
#  'ENSG00000212171': 'rRNA_pseudogene',
#  'ENSG00000206635': 'snRNA',
#  'ENSG00000277948': 'misc_RNA',
#  'ENSG00000216171': 'miRNA',
#  'ENSG00000199815': 'snoRNA',
#  'ENSG00000200114': 'rRNA_pseudogene',
#  'ENSG00000274606': 'misc_RNA',
#  'ENSG00000200983': 'snoRNA',
#  'ENSG00000251763': 'snRNA',
#  'ENSG00000200750': 'misc_RNA',
#  'ENSG00000273886': 'misc_RNA',
#  'ENSG00000273501': 'snRNA',
#  'ENSG00000276577': 'snRNA',
#  'ENSG00000252257': 'misc_RNA',
#  'ENSG00000275420': 'misc_RNA',
#  'ENSG00000280864': 'lncRNA',
#  'ENSG00000252429': 'snRNA',
#  'ENSG00000263871': 'snRNA',
#  'ENSG00000199489': 'snoRNA',
#  'ENSG00000212332': 'snRNA',
#  'ENSG00000244034': 'misc_RNA',
#  'ENSG00000252810': 'snRNA',
#  'ENSG00000244544': 'misc_RNA',
#  'ENSG00000200469': 'snRNA',
#  'ENSG00000206991': 'snRNA',
#  'ENSG00000252448': 'snoRNA',
#  'ENSG00000238406': 'snRNA',
#  'ENSG00000212479': 'snoRNA',
#  'ENSG00000206781': 'misc_RNA',
#  'ENSG00000277139': 'snRNA',
#  'ENSG00000207181': 'snoRNA',
#  'ENSG00000252398': 'misc_RNA',
#  'ENSG00000202039': 'snRNA',
#  'ENSG00000200102': 'snRNA',
#  'ENSG00000200903': 'snRNA',
#  'ENSG00000200350': 'snRNA',
#  'ENSG00000242696': 'misc_RNA',
#  'ENSG00000252558': 'snRNA',
#  'ENSG00000273975': 'misc_RNA',
#  'ENSG00000223064': 'snRNA',
#  'ENSG00000222546': 'rRNA_pseudogene',
#  'ENSG00000272028': 'snRNA',
#  'ENSG00000252045': 'snoRNA',
#  'ENSG00000206672': 'misc_RNA',
#  'ENSG00000199509': 'rRNA_pseudogene',
#  'ENSG00000274171': 'misc_RNA',
#  'ENSG00000221527': 'snRNA',
#  'ENSG00000278498': 'misc_RNA',
#  'ENSG00000201245': 'snoRNA',
#  'ENSG00000276516': 'misc_RNA',
#  'ENSG00000251791': 'scaRNA',
#  'ENSG00000200475': 'misc_RNA',
#  'ENSG00000201728': 'rRNA_pseudogene',
#  'ENSG00000200106': 'snRNA',
#  'ENSG00000202374': 'snoRNA',
#  'ENSG00000276839': 'misc_RNA',
#  'ENSG00000200789': 'snRNA',
#  'ENSG00000251805': 'scaRNA',
#  'ENSG00000202408': 'snRNA',
#  'ENSG00000238788': 'snRNA',
#  'ENSG00000199385': 'snRNA',
#  'ENSG00000272020': 'snRNA',
#  'ENSG00000277599': 'misc_RNA',
#  'ENSG00000251960': 'snRNA',
#  'ENSG00000200495': 'snRNA',
#  'ENSG00000252645': 'snRNA',
#  'ENSG00000276003': 'misc_RNA',
#  'ENSG00000239888': 'misc_RNA',
#  'ENSG00000276396': 'misc_RNA',
#  'ENSG00000273979': 'misc_RNA',
#  'ENSG00000212496': 'snRNA',
#  'ENSG00000277004': 'rRNA_pseudogene',
#  'ENSG00000207174': 'snoRNA',
#  'ENSG00000206596': 'snRNA',
#  'ENSG00000274475': 'misc_RNA',
#  'ENSG00000252396': 'misc_RNA',
#  'ENSG00000202251': 'misc_RNA',
#  'ENSG00000212418': 'misc_RNA',
#  'ENSG00000251880': 'snRNA',
#  'ENSG00000278757': 'snRNA',
#  'ENSG00000222617': 'misc_RNA',
#  'ENSG00000202283': 'snoRNA',
#  'ENSG00000203436': 'misc_RNA',
#  'ENSG00000252470': 'snRNA',
#  'ENSG00000200898': 'snRNA',
#  'ENSG00000213167': 'misc_RNA',
#  'ENSG00000223238': 'rRNA_pseudogene',
#  'ENSG00000212269': 'snRNA',
#  'ENSG00000252671': 'misc_RNA',
#  'ENSG00000275213': 'misc_RNA',
#  'ENSG00000238754': 'snoRNA',
#  'ENSG00000212466': 'snRNA',
#  'ENSG00000252050': 'snoRNA',
#  'ENSG00000199266': 'snoRNA',
#  'ENSG00000200418': 'snoRNA',
#  'ENSG00000199584': 'misc_RNA',
#  'ENSG00000200890': 'rRNA_pseudogene',
#  'ENSG00000252597': 'snRNA',
#  'ENSG00000241791': 'misc_RNA',
#  'ENSG00000207144': 'snRNA',
#  'ENSG00000278747': 'snRNA',
#  'ENSG00000212526': 'snRNA',
#  'ENSG00000223335': 'snRNA',
#  'ENSG00000252581': 'snRNA',
#  'ENSG00000199985': 'rRNA_pseudogene',
#  'ENSG00000200036': 'rRNA_pseudogene',
#  'ENSG00000206926': 'snRNA',
#  'ENSG00000273974': 'misc_RNA',
#  'ENSG00000276685': 'misc_RNA',
#  'ENSG00000206836': 'snRNA',
#  'ENSG00000263608': 'misc_RNA',
#  'ENSG00000206850': 'misc_RNA',
#  'ENSG00000251864': 'misc_RNA',
#  'ENSG00000201403': 'snoRNA',
#  'ENSG00000201157': 'snoRNA',
#  'ENSG00000277580': 'snRNA',
#  'ENSG00000212532': 'snoRNA',
#  'ENSG00000252751': 'snRNA',
#  'ENSG00000277583': 'misc_RNA',
#  'ENSG00000277903': 'snRNA',
#  'ENSG00000201217': 'misc_RNA',
#  'ENSG00000207445': 'snoRNA',
#  'ENSG00000201297': 'misc_RNA',
#  'ENSG00000277995': 'snoRNA',
#  'ENSG00000278026': 'misc_RNA',
#  'ENSG00000222268': 'rRNA_pseudogene',
#  'ENSG00000278020': 'misc_RNA',
#  'ENSG00000201618': 'rRNA_pseudogene',
#  'ENSG00000207333': 'snRNA',
#  'ENSG00000212542': 'rRNA_pseudogene',
#  'ENSG00000238311': 'snoRNA',
#  'ENSG00000252117': 'snRNA',
#  'ENSG00000201766': 'rRNA_pseudogene',
#  'ENSG00000273624': 'snRNA',
#  'ENSG00000278151': 'misc_RNA',
#  'ENSG00000238908': 'rRNA_pseudogene',
#  'ENSG00000200917': 'snRNA',
#  'ENSG00000201394': 'rRNA_pseudogene',
#  'ENSG00000229686': 'snoRNA',
#  'ENSG00000200220': 'snRNA',
#  'ENSG00000265033': 'misc_RNA',
#  'ENSG00000273537': 'misc_RNA',
#  'ENSG00000238854': 'snoRNA',
#  'ENSG00000275823': 'misc_RNA',
#  'ENSG00000266150': 'miRNA',
#  'ENSG00000274127': 'misc_RNA',
#  'ENSG00000243370': 'misc_RNA',
#  'ENSG00000251869': 'scaRNA',
#  'ENSG00000252275': 'snRNA',
#  'ENSG00000264720': 'miRNA',
#  'ENSG00000264251': 'misc_RNA',
#  'ENSG00000239039': 'snoRNA',
#  'ENSG00000201315': 'misc_RNA',
#  'ENSG00000215930': 'miRNA',
#  'ENSG00000275776': 'misc_RNA',
#  'ENSG00000201780': 'snRNA',
#  'ENSG00000276871': 'rRNA',
#  'ENSG00000212266': 'snoRNA',
#  'ENSG00000212605': 'snRNA',
#  'ENSG00000199577': 'snRNA',
#  'ENSG00000265831': 'miRNA',
#  'ENSG00000207100': 'snoRNA',
#  'ENSG00000212306': 'misc_RNA',
#  'ENSG00000240639': 'misc_RNA',
#  'ENSG00000221375': 'snRNA',
#  'ENSG00000239152': 'rRNA_pseudogene',
#  'ENSG00000264800': 'miRNA',
#  'ENSG00000199515': 'misc_RNA',
#  'ENSG00000212360': 'snRNA',
#  'ENSG00000200367': 'snoRNA',
#  'ENSG00000200553': 'misc_RNA',
#  'ENSG00000202513': 'snRNA',
#  'ENSG00000284293': 'miRNA',
#  'ENSG00000252061': 'snRNA',
#  'ENSG00000212257': 'snRNA',
#  'ENSG00000252888': 'snoRNA',
#  'ENSG00000252745': 'rRNA_pseudogene',
#  'ENSG00000264295': 'miRNA',
#  'ENSG00000252347': 'snRNA',
#  'ENSG00000221044': 'snoRNA',
#  'ENSG00000207233': 'snoRNA',
#  'ENSG00000265141': 'misc_RNA',
#  'ENSG00000252655': 'misc_RNA',
#  'ENSG00000216179': 'miRNA',
#  'ENSG00000274742': 'misc_RNA',
#  'ENSG00000238998': 'snRNA',
#  'ENSG00000251994': 'snRNA',
#  'ENSG00000201992': 'snoRNA',
#  'ENSG00000243373': 'misc_RNA',
#  'ENSG00000252042': 'misc_RNA',
#  'ENSG00000207702': 'miRNA',
#  'ENSG00000263969': 'misc_RNA',
#  'ENSG00000264317': 'misc_RNA',
#  'ENSG00000244236': 'misc_RNA',
#  'ENSG00000265753': 'misc_RNA',
#  'ENSG00000264397': 'miRNA',
#  'ENSG00000243267': 'misc_RNA',
#  'ENSG00000242863': 'misc_RNA',
#  'ENSG00000200834': 'misc_RNA',
#  'ENSG00000276609': 'misc_RNA',
#  'ENSG00000266232': 'miRNA',
#  'ENSG00000283369': 'snRNA',
#  'ENSG00000252680': 'rRNA_pseudogene',
#  'ENSG00000275780': 'rRNA_pseudogene',
#  'ENSG00000284368': 'miRNA',
#  'ENSG00000277689': 'misc_RNA',
#  'ENSG00000265920': 'snRNA',
#  'ENSG00000238423': 'snoRNA',
#  'ENSG00000277379': 'miRNA',
#  'ENSG00000274467': 'rRNA_pseudogene',
#  'ENSG00000244356': 'misc_RNA',
#  'ENSG00000201410': 'snoRNA',
#  'ENSG00000267828': 'misc_RNA',
#  'ENSG00000264757': 'miRNA',
#  'ENSG00000253015': 'misc_RNA',
#  'ENSG00000222078': 'misc_RNA',
#  'ENSG00000283871': 'miRNA',
#  'ENSG00000243059': 'misc_RNA',
#  'ENSG00000276103': 'snRNA',
#  'ENSG00000212454': 'rRNA_pseudogene',
#  'ENSG00000212246': 'snRNA',
#  'ENSG00000283829': 'miRNA',
#  'ENSG00000275655': 'misc_RNA',
#  'ENSG00000199711': 'misc_RNA',
#  'ENSG00000199285': 'misc_RNA',
#  'ENSG00000265160': 'miRNA',
#  'ENSG00000202402': 'misc_RNA',
#  'ENSG00000206958': 'snoRNA',
#  'ENSG00000222427': 'rRNA_pseudogene',
#  'ENSG00000208308': 'snoRNA',
#  'ENSG00000284370': 'miRNA',
#  'ENSG00000276493': 'misc_RNA',
#  'ENSG00000240106': 'misc_RNA',
#  'ENSG00000277418': 'rRNA',
#  'ENSG00000202406': 'misc_RNA',
#  'ENSG00000284064': 'miRNA',
#  'ENSG00000202190': 'misc_RNA',
#  'ENSG00000199756': 'misc_RNA',
#  'ENSG00000272230': 'miRNA',
#  'ENSG00000252321': 'misc_RNA',
#  'ENSG00000275472': 'misc_RNA',
#  'ENSG00000200101': 'snRNA',
#  'ENSG00000265660': 'miRNA',
#  'ENSG00000274710': 'misc_RNA',
#  'ENSG00000252346': 'rRNA_pseudogene',
#  'ENSG00000274581': 'snoRNA',
#  'ENSG00000199787': 'snoRNA',
#  'ENSG00000283751': 'miRNA',
#  'ENSG00000273846': 'misc_RNA',
#  'ENSG00000200360': 'snRNA',
#  'ENSG00000200718': 'misc_RNA',
#  'ENSG00000212499': 'rRNA_pseudogene',
#  'ENSG00000200243': 'misc_RNA',
#  'ENSG00000202008': 'misc_RNA',
#  'ENSG00000207258': 'misc_RNA',
#  'ENSG00000206791': 'snRNA',
#  'ENSG00000238529': 'snRNA',
#  'ENSG00000201331': 'snoRNA',
#  'ENSG00000244399': 'misc_RNA',
#  'ENSG00000276470': 'misc_RNA',
#  'ENSG00000252881': 'snRNA',
#  'ENSG00000265745': 'misc_RNA',
#  'ENSG00000252930': 'snRNA',
#  'ENSG00000275933': 'misc_RNA',
#  'ENSG00000251898': 'scaRNA',
#  'ENSG00000202239': 'snRNA',
#  'ENSG00000240199': 'misc_RNA',
#  'ENSG00000275698': 'misc_RNA',
#  'ENSG00000278752': 'misc_RNA',
#  'ENSG00000265838': 'snRNA',
#  'ENSG00000252937': 'snRNA',
#  'ENSG00000207089': 'snRNA',
#  'ENSG00000238730': 'snRNA',
#  'ENSG00000243173': 'misc_RNA',
#  'ENSG00000212165': 'snoRNA',
#  'ENSG00000252574': 'snRNA',
#  'ENSG00000206924': 'snRNA',
#  'ENSG00000207037': 'snRNA',
#  'ENSG00000201900': 'misc_RNA',
#  'ENSG00000277908': 'snRNA',
#  'ENSG00000242066': 'misc_RNA',
#  'ENSG00000207448': 'snRNA',
#  'ENSG00000251707': 'snRNA',
#  'ENSG00000206865': 'misc_RNA',
#  'ENSG00000221507': 'snRNA',
#  'ENSG00000207148': 'misc_RNA',
#  'ENSG00000201683': 'misc_RNA',
#  'ENSG00000251882': 'snRNA',
#  'ENSG00000222102': 'misc_RNA',
#  'ENSG00000264379': 'snoRNA',
#  'ENSG00000212527': 'rRNA_pseudogene',
#  'ENSG00000201869': 'snRNA',
#  'ENSG00000277118': 'misc_RNA',
#  'ENSG00000201435': 'snRNA',
#  'ENSG00000276544': 'misc_RNA',
#  'ENSG00000212397': 'snoRNA',
#  'ENSG00000200763': 'snRNA',
#  'ENSG00000199395': 'rRNA_pseudogene',
#  'ENSG00000252827': 'misc_RNA',
#  'ENSG00000262132': 'rRNA_pseudogene',
#  'ENSG00000201570': 'snRNA',
#  'ENSG00000280502': 'misc_RNA',
#  'ENSG00000266828': 'misc_RNA',
#  'ENSG00000252673': 'rRNA_pseudogene',
#  'ENSG00000252126': 'snRNA',
#  'ENSG00000202310': 'misc_RNA',
#  'ENSG00000201160': 'misc_RNA',
#  'ENSG00000265078': 'misc_RNA',
#  'ENSG00000273764': 'misc_RNA',
#  'ENSG00000222614': 'misc_RNA',
#  'ENSG00000199301': 'snRNA',
#  'ENSG00000212452': 'snoRNA',
#  'ENSG00000239579': 'misc_RNA',
#  'ENSG00000265684': 'misc_RNA',
#  'ENSG00000202377': 'snoRNA',
#  'ENSG00000265248': 'snRNA',
#  'ENSG00000278189': 'rRNA',
#  'ENSG00000200332': 'misc_RNA',
#  'ENSG00000252704': 'misc_RNA',
#  'ENSG00000212153': 'snRNA',
#  'ENSG00000222613': 'misc_RNA',
#  'ENSG00000271924': 'rRNA_pseudogene',
#  'ENSG00000265921': 'snRNA',
#  'ENSG00000206698': 'snRNA',
#  'ENSG00000238934': 'snoRNA',
#  'ENSG00000222872': 'snRNA',
#  'ENSG00000276439': 'misc_RNA',
#  'ENSG00000200688': 'misc_RNA',
#  'ENSG00000212512': 'misc_RNA',
#  'ENSG00000263876': 'misc_RNA',
#  'ENSG00000207027': 'snoRNA',
#  'ENSG00000201847': 'snoRNA',
#  'ENSG00000252647': 'rRNA_pseudogene',
#  'ENSG00000252800': 'scaRNA',
#  'ENSG00000239149': 'snoRNA',
#  'ENSG00000274686': 'misc_RNA',
#  'ENSG00000201356': 'rRNA_pseudogene',
#  'ENSG00000201198': 'snRNA',
#  'ENSG00000243959': 'misc_RNA',
#  'ENSG00000265495': 'snoRNA',
#  'ENSG00000239102': 'snRNA',
#  'ENSG00000207196': 'misc_RNA',
#  'ENSG00000201271': 'snRNA',
#  'ENSG00000199530': 'misc_RNA',
#  'ENSG00000253070': 'snRNA',
#  'ENSG00000201075': 'misc_RNA',
#  'ENSG00000212473': 'snRNA',
#  'ENSG00000276988': 'misc_RNA',
#  'ENSG00000207195': 'misc_RNA',
#  'ENSG00000252385': 'snRNA',
#  'ENSG00000265255': 'misc_RNA',
#  'ENSG00000251915': 'rRNA_pseudogene',
#  'ENSG00000243066': 'misc_RNA',
#  'ENSG00000243313': 'misc_RNA',
#  'ENSG00000201818': 'misc_RNA',
#  'ENSG00000277234': 'snRNA',
#  'ENSG00000212378': 'snoRNA',
#  'ENSG00000238912': 'misc_RNA',
#  'ENSG00000283551': 'snoRNA',
#  'ENSG00000201868': 'misc_RNA',
#  'ENSG00000238711': 'misc_RNA',
#  'ENSG00000199488': 'snRNA',
#  'ENSG00000244610': 'misc_RNA',
#  'ENSG00000201620': 'rRNA_pseudogene',
#  'ENSG00000239169': 'snoRNA',
#  'ENSG00000223026': 'misc_RNA',
#  'ENSG00000252580': 'snoRNA',
#  'ENSG00000202056': 'rRNA_pseudogene',
#  'ENSG00000280646': 'rRNA_pseudogene',
#  'ENSG00000222721': 'misc_RNA',
#  'ENSG00000272015': 'snoRNA',
#  'ENSG00000285609': 'rRNA_pseudogene',
#  'ENSG00000252068': 'snRNA',
#  'ENSG00000273866': 'misc_RNA',
#  'ENSG00000276314': 'snoRNA',
#  'ENSG00000273499': 'snoRNA',
#  'ENSG00000240014': 'misc_RNA',
#  'ENSG00000240250': 'misc_RNA',
#  'ENSG00000276642': 'snRNA',
#  'ENSG00000199453': 'snoRNA',
#  'ENSG00000207004': 'snRNA',
#  'ENSG00000278233': 'rRNA',
#  'ENSG00000201384': 'snoRNA',
#  'ENSG00000252292': 'misc_RNA',
#  'ENSG00000252943': 'snRNA',
#  'ENSG00000238723': 'misc_RNA',
#  'ENSG00000252902': 'rRNA_pseudogene',
#  'ENSG00000275231': 'misc_RNA',
#  'ENSG00000252073': 'snRNA',
#  'ENSG00000222112': 'misc_RNA',
#  'ENSG00000276100': 'misc_RNA',
#  'ENSG00000288590': 'lncRNA',
#  'ENSG00000288599': 'protein_coding',
#  'ENSG00000288594': 'TEC',
#  'ENSG00000207969': 'miRNA',
#  'ENSG00000222616': 'misc_RNA',
#  'ENSG00000201674': 'snoRNA',
#  'ENSG00000212434': 'snoRNA',
#  'ENSG00000201785': 'snoRNA',
#  'ENSG00000238645': 'snoRNA',
#  'ENSG00000241542': 'misc_RNA',
#  'ENSG00000206688': 'snoRNA',
#  'ENSG00000222604': 'snoRNA',
#  'ENSG00000200480': 'snoRNA',
#  'ENSG00000283146': 'miRNA',
#  'ENSG00000274396': 'misc_RNA',
#  'ENSG00000200816': 'snoRNA',
#  'ENSG00000212211': 'snoRNA',
#  'ENSG00000206612': 'snoRNA',
#  'ENSG00000283272': 'sRNA',
#  'ENSG00000252336': 'rRNA_pseudogene',
#  'ENSG00000252693': 'snoRNA',
#  'ENSG00000284087': 'miRNA',
#  'ENSG00000265439': 'misc_RNA',
#  'ENSG00000264353': 'misc_RNA',
#  'ENSG00000206605': 'snRNA',
#  'ENSG00000206693': 'snoRNA',
#  'ENSG00000283505': 'miRNA',
#  'ENSG00000241652': 'misc_RNA',
#  'ENSG00000207204': 'snRNA',
#  'ENSG00000199575': 'snoRNA',
#  'ENSG00000238777': 'snRNA',
#  'ENSG00000207641': 'miRNA',
#  'ENSG00000264847': 'misc_RNA',
#  'ENSG00000252622': 'snRNA',
#  'ENSG00000266295': 'snoRNA',
#  'ENSG00000273544': 'snoRNA',
#  'ENSG00000212289': 'rRNA_pseudogene',
#  'ENSG00000206785': 'snoRNA',
#  'ENSG00000263372': 'miRNA',
#  'ENSG00000274760': 'misc_RNA',
#  'ENSG00000265810': 'miRNA',
#  'ENSG00000212237': 'rRNA_pseudogene',
#  'ENSG00000276256': 'protein_coding',
#  'ENSG00000261867': 'snRNA',
#  'ENSG00000199094': 'miRNA',
#  'ENSG00000206998': 'misc_RNA',
#  'ENSG00000222783': 'misc_RNA',
#  'ENSG00000199158': 'miRNA',
#  'ENSG00000243770': 'misc_RNA',
#  'ENSG00000251804': 'snRNA',
#  'ENSG00000265059': 'snRNA',
#  'ENSG00000201071': 'misc_RNA',
#  'ENSG00000280704': 'snoRNA',
#  'ENSG00000208036': 'miRNA',
#  'ENSG00000223271': 'misc_RNA',
#  'ENSG00000199217': 'snRNA',
#  'ENSG00000276770': 'miRNA',
#  'ENSG00000207689': 'miRNA',
#  'ENSG00000201675': 'snoRNA',
#  'ENSG00000264474': 'miRNA',
#  'ENSG00000212259': 'snRNA',
#  'ENSG00000201827': 'snoRNA',
#  'ENSG00000274230': 'misc_RNA',
#  'ENSG00000222937': 'snoRNA',
#  'ENSG00000264342': 'miRNA',
#  'ENSG00000276746': 'misc_RNA',
#  'ENSG00000278515': 'snRNA',
#  'ENSG00000263529': 'misc_RNA',
#  'ENSG00000284464': 'miRNA',
#  'ENSG00000206713': 'misc_RNA',
#  'ENSG00000264056': 'miRNA',
#  'ENSG00000207508': 'snRNA',
#  'ENSG00000238431': 'snRNA',
#  'ENSG00000207627': 'miRNA',
#  'ENSG00000238523': 'snRNA',
#  'ENSG00000242769': 'misc_RNA',
#  'ENSG00000252802': 'misc_RNA',
#  'ENSG00000278433': 'miRNA',
#  'ENSG00000251706': 'snRNA',
#  'ENSG00000221430': 'miRNA',
#  'ENSG00000252777': 'scaRNA',
#  'ENSG00000283971': 'miRNA',
#  'ENSG00000242889': 'misc_RNA',
#  'ENSG00000199809': 'rRNA_pseudogene',
#  'ENSG00000202241': 'misc_RNA',
#  'ENSG00000275982': 'misc_RNA',
#  'ENSG00000277464': 'misc_RNA',
#  'ENSG00000252162': 'snRNA',
#  'ENSG00000283469': 'miRNA',
#  'ENSG00000271898': 'miRNA',
#  'ENSG00000223118': 'misc_RNA',
#  'ENSG00000207638': 'miRNA',
#  'ENSG00000252128': 'snoRNA',
#  'ENSG00000199368': 'snRNA',
#  'ENSG00000212228': 'snoRNA',
#  'ENSG00000252437': 'rRNA_pseudogene',
#  'ENSG00000207634': 'miRNA',
#  'ENSG00000222488': 'snRNA',
#  'ENSG00000207802': 'miRNA',
#  'ENSG00000251956': 'snRNA',
#  'ENSG00000207193': 'misc_RNA',
#  'ENSG00000222246': 'miRNA',
#  'ENSG00000207263': 'snoRNA',
#  'ENSG00000206822': 'misc_RNA',
#  'ENSG00000206845': 'snRNA',
#  'ENSG00000276640': 'misc_RNA',
#  'ENSG00000207788': 'miRNA',
#  'ENSG00000283880': 'miRNA',
#  'ENSG00000249784': 'scaRNA',
#  'ENSG00000283394': 'miRNA',
#  'ENSG00000240186': 'misc_RNA',
#  'ENSG00000274097': 'rRNA',
#  'ENSG00000240347': 'misc_RNA',
#  'ENSG00000243549': 'misc_RNA',
#  'ENSG00000206907': 'snRNA',
#  'ENSG00000281311': 'snoRNA',
#  'ENSG00000200211': 'misc_RNA',
#  'ENSG00000264060': 'miRNA',
#  'ENSG00000275107': 'miRNA',
#  'ENSG00000274111': 'miRNA',
#  'ENSG00000222973': 'snRNA',
#  'ENSG00000244501': 'misc_RNA',
#  'ENSG00000241552': 'misc_RNA',
#  'ENSG00000212304': 'snoRNA',
#  'ENSG00000202195': 'misc_RNA',
#  'ENSG00000199645': 'snRNA',
#  'ENSG00000207996': 'miRNA',
#  'ENSG00000202111': 'misc_RNA',
#  'ENSG00000274172': 'miRNA',
#  'ENSG00000202351': 'misc_RNA',
#  'ENSG00000252260': 'rRNA_pseudogene',
#  'ENSG00000207948': 'miRNA',
#  'ENSG00000206908': 'snRNA',
#  'ENSG00000201085': 'snRNA',
#  'ENSG00000212302': 'snoRNA',
#  'ENSG00000267195': 'miRNA',
#  'ENSG00000284152': 'miRNA',
#  'ENSG00000265005': 'miRNA',
#  'ENSG00000275574': 'misc_RNA',
#  'ENSG00000251913': 'snRNA',
#  'ENSG00000199381': 'snRNA',
#  'ENSG00000252913': 'snRNA',
#  'ENSG00000206806': 'misc_RNA',
#  'ENSG00000238680': 'snRNA',
#  'ENSG00000273778': 'miRNA',
#  'ENSG00000221060': 'snoRNA',
#  'ENSG00000241461': 'misc_RNA',
#  'ENSG00000283340': 'miRNA',
#  'ENSG00000207993': 'miRNA',
#  'ENSG00000243125': 'misc_RNA',
#  'ENSG00000238813': 'misc_RNA',
#  'ENSG00000201510': 'misc_RNA',
#  'ENSG00000201988': 'misc_RNA',
#  'ENSG00000221788': 'miRNA',
#  'ENSG00000253031': 'rRNA_pseudogene',
#  'ENSG00000266458': 'miRNA',
#  'ENSG00000252369': 'snRNA',
#  'ENSG00000275399': 'protein_coding',
#  'ENSG00000207495': 'misc_RNA',
#  'ENSG00000277967': 'misc_RNA',
#  'ENSG00000278520': 'miRNA',
#  'ENSG00000263987': 'miRNA',
#  'ENSG00000278794': 'misc_RNA',
#  'ENSG00000274978': 'snRNA',
#  'ENSG00000223168': 'misc_RNA',
#  'ENSG00000206820': 'snRNA',
#  'ENSG00000266041': 'miRNA',
#  'ENSG00000207000': 'snRNA',
#  'ENSG00000201990': 'misc_RNA',
#  'ENSG00000206640': 'misc_RNA',
#  'ENSG00000252854': 'misc_RNA',
#  'ENSG00000274940': 'miRNA',
#  'ENSG00000200884': 'misc_RNA',
#  'ENSG00000265372': 'miRNA',
#  'ENSG00000252952': 'snRNA',
#  'ENSG00000278465': 'miRNA',
#  'ENSG00000252408': 'snoRNA',
#  'ENSG00000238610': 'snRNA',
#  'ENSG00000251990': 'rRNA_pseudogene',
#  'ENSG00000222715': 'miRNA',
#  'ENSG00000281394': 'scaRNA',
#  'ENSG00000207371': 'misc_RNA',
#  'ENSG00000222092': 'snRNA',
#  'ENSG00000207220': 'snRNA',
#  'ENSG00000251971': 'snRNA',
#  'ENSG00000253026': 'snRNA',
#  'ENSG00000212595': 'rRNA',
#  'ENSG00000284568': 'miRNA',
#  'ENSG00000277001': 'misc_RNA',
#  'ENSG00000265719': 'miRNA',
#  'ENSG00000221028': 'miRNA',
#  'ENSG00000252524': 'misc_RNA',
#  'ENSG00000252005': 'snRNA',
#  'ENSG00000199469': 'snRNA',
#  'ENSG00000266738': 'miRNA',
#  'ENSG00000200120': 'misc_RNA',
#  'ENSG00000276102': 'miRNA',
#  'ENSG00000265370': 'miRNA',
#  'ENSG00000207116': 'snRNA',
#  'ENSG00000206935': 'snRNA',
#  'ENSG00000201318': 'snoRNA',
#  'ENSG00000238498': 'snoRNA',
#  'ENSG00000207923': 'miRNA',
#  'ENSG00000207805': 'miRNA',
#  'ENSG00000212380': 'snoRNA',
#  'ENSG00000206911': 'misc_RNA',
#  'ENSG00000266570': 'miRNA',
#  'ENSG00000200213': 'snRNA',
#  'ENSG00000207275': 'snRNA',
#  'ENSG00000277864': 'scaRNA',
#  'ENSG00000200406': 'snoRNA',
#  'ENSG00000283637': 'miRNA',
#  'ENSG00000207713': 'miRNA',
#  'ENSG00000264906': 'miRNA',
#  'ENSG00000200686': 'misc_RNA',
#  'ENSG00000239005': 'snoRNA',
#  'ENSG00000285776': 'rRNA_pseudogene',
#  'ENSG00000252519': 'snRNA',
#  'ENSG00000266887': 'miRNA',
#  'ENSG00000266655': 'miRNA',
#  'ENSG00000263616': 'misc_RNA',
#  'ENSG00000278048': 'snRNA',
#  'ENSG00000207719': 'miRNA',
#  'ENSG00000283785': 'miRNA',
#  'ENSG00000274284': 'misc_RNA',
#  'ENSG00000222610': 'snRNA',
#  'ENSG00000199075': 'miRNA',
#  'ENSG00000283346': 'miRNA',
#  'ENSG00000242928': 'misc_RNA',
#  'ENSG00000206889': 'snRNA',
#  'ENSG00000280554': 'snoRNA',
#  'ENSG00000284269': 'miRNA',
#  'ENSG00000201308': 'snRNA',
#  'ENSG00000252204': 'snoRNA',
#  'ENSG00000284078': 'miRNA',
#  'ENSG00000266307': 'miRNA',
#  'ENSG00000266439': 'misc_RNA',
#  'ENSG00000207300': 'misc_RNA',
#  'ENSG00000207761': 'miRNA',
#  'ENSG00000200685': 'misc_RNA',
#  'ENSG00000221287': 'miRNA',
#  'ENSG00000201201': 'misc_RNA',
#  'ENSG00000200471': 'snRNA',
#  'ENSG00000252080': 'snRNA',
#  'ENSG00000207959': 'miRNA',
#  'ENSG00000207019': 'snRNA',
#  'ENSG00000283795': 'miRNA',
#  'ENSG00000202199': 'snRNA',
#  'ENSG00000200488': 'misc_RNA',
#  'ENSG00000284517': 'miRNA',
#  'ENSG00000281159': 'scaRNA',
#  'ENSG00000252762': 'snoRNA',
#  'ENSG00000265957': 'miRNA',
#  ...}

# %%
def biomart_id_to_type(key):
    if (key in eid_to_type):
        return eid_to_type[key]
    else:
        return None

# %%
biomart_gene_types = np.transpose([ biomart_id_to_type(str(key)[2:-1]) for key in eids ])
biomart_filtered_types = biomart_gene_types[biomart_gene_types!=None]
counts = np.unique(biomart_filtered_types, return_counts=True)
counts
# Out:
# (array(['IG_C_gene', 'IG_C_pseudogene', 'IG_D_gene', 'IG_J_gene',
#         'IG_J_pseudogene', 'IG_V_gene', 'IG_V_pseudogene', 'Mt_rRNA',
#         'Mt_tRNA', 'TEC', 'TR_C_gene', 'TR_J_gene', 'TR_V_gene',
#         'TR_V_pseudogene', 'lncRNA', 'miRNA', 'misc_RNA',
#         'polymorphic_pseudogene', 'processed_pseudogene', 'protein_coding',
#         'pseudogene', 'rRNA', 'rRNA_pseudogene', 'scRNA', 'scaRNA',
#         'snRNA', 'snoRNA', 'transcribed_processed_pseudogene',
#         'transcribed_unitary_pseudogene',
#         'transcribed_unprocessed_pseudogene',
#         'translated_processed_pseudogene',
#         'translated_unprocessed_pseudogene', 'unitary_pseudogene',
#         'unprocessed_pseudogene', 'vaultRNA'], dtype=object),
#  array([   13,     7,    22,     7,     2,   140,    92,     2,    16,
#           688,     6,    11,    94,    14,  9901,   279,   500,    19,
#          4782, 18463,     9,     8,    77,     1,    16,   384,   214,
#           353,   101,   623,     1,     1,    27,   790,     1]))

# %%
g_types = { 
    "ig": ['IG_C_gene', 'IG_C_pseudogene', 'IG_D_gene', 'IG_J_gene',
        'IG_J_pseudogene', 'IG_V_gene', 'IG_V_pseudogene'],
    "mito": ['Mt_rRNA','Mt_tRNA'], 
    "tr": ['TR_C_gene', 'TR_J_gene', 'TR_V_gene','TR_V_pseudogene'], 
    "pseudo": ['pseudogene', 'transcribed_processed_pseudogene',
               'transcribed_unitary_pseudogene',
               'transcribed_unprocessed_pseudogene',
               'translated_processed_pseudogene',
               'translated_unprocessed_pseudogene',
               'unitary_pseudogene', 'unprocessed_pseudogene', 
               'polymorphic_pseudogene', 'processed_pseudogene'
              ], 
    "rRNA": ["rRNA", 'rRNA_pseudogene'], 
    "other_RNA": ['scRNA', 'scaRNA','snRNA', 'snoRNA', 'misc_RNA', 'vaultRNA'], 
    "protein_coding": ["protein_coding"], 
    "TEC": ["TEC"], "lncRNA": ["lncRNA"], "miRNA": ["miRNA"]
}

flipped = {}
keys = list(g_types.keys())
for i in range(len(g_types)):
    key = keys[i]
    val = g_types[key]
    for j in val:
        flipped[j] = key

# %%
print(len(flipped))
print(len(counts[0]))
# Out:
# 35
# 35

# %%
gene_exp = pd.DataFrame(np.matrix(gene_exp))

# %%
def subcorrelation(gtypes):
    """
    Calculate subcorrelation by looping through the 
    gene types in order, putting their indices into
    categories and then getting the correlation matrix.
    """
    g_idx_dict = {"None": []}
    for idx in range(len(gtypes)):
        gtype = gtypes[idx]
        if gtype == None: continue 
        category = flipped[gtype]
        if category not in g_idx_dict: 
            g_idx_dict[category] = []
        g_idx_dict[category].append(idx)
        
    print("The dict has {} keys".format(len(g_idx_dict)))
    
    for key in g_idx_dict: 
        rows = g_idx_dict[key]
        print("{} has {} values".format(key, len(rows)))
        gene_matrix = gene_exp.iloc[rows]
        corr = np.triu(np.corrcoef(gene_matrix))
        np.fill_diagonal(corr, 0)
        subcor = data.create_dataset("{}_corr".format(key), data=corr)
        gene_order = meta.create_dataset("{}_genes".format(key), data=rows)

# %%
subcorrelation(biomart_gene_types)
# Out:
# The dict has 1 keys
# None has 886 values

# %%
print(18463+6706+9901+283+1116+279+85+125+18+688)
print(sum(counts[1]))

# %%
print(list(data.keys()))
print(list(meta.keys()))
f.close()
# Out:
# ['None_corr', 'TEC_corr', 'expression', 'ig_corr', 'lncRNA_corr', 'miRNA_corr', 'mito_corr', 'other_RNA_corr', 'processed_expression', 'protein_coding_corr', 'pseudo_corr', 'rRNA_corr', 'tr_corr']
# ['None_genes', 'TEC_genes', 'ensembl_id', 'genes', 'ig_genes', 'lncRNA_genes', 'miRNA_genes', 'mito_genes', 'other_RNA_genes', 'protein_coding_genes', 'pseudo_genes', 'rRNA_genes', 'tr_genes']

# %% [markdown]
# # Correlation matrix

# %%
# get the upper triangle and make the diagonal zero of the correlation matrix
cor = np.triu(np.corrcoef(exp))
np.fill_diagonal(cor,0)

# %%
# correlation matrix 
cor
# Out:
# array([[ 0.        ,  0.26270527,  0.14656306, ...,  0.25640679,
#         -0.17067008,  0.21301928],
#        [ 0.        ,  0.        ,  0.00520883, ...,  0.05731222,
#         -0.06433745, -0.03968901],
#        [ 0.        ,  0.        ,  0.        , ..., -0.08012387,
#          0.06000723,  0.02973038],
#        ...,
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#         -0.07912547,  0.33178938],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.00034693],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ]])

# %%
correlation_matrix = f.create_dataset("correlation_matrix", data=cor)

# %%
cor = f['correlation_matrix']

# %%
# flatten the matrix to get the counts 
flat = np.matrix(cor).flatten()

# %%
# remove the zero values in the matrix
flat = flat[flat != 0]

# %%
# get the counts for the unique letters in the matrix 
counts = np.unique(flat, return_counts=True)
counts
# Out:
# (matrix([[-0.88279573, -0.87689072, -0.87543078, ...,  0.98587739,
#            0.98638712,  0.98646871]]), array([0, 0, 0, ..., 1, 1, 1]))

# %%
# Number of 1 values 
counts[1][-1]
# Out:
# 1

# %%
# Number of counts total (total number of correlations)
sum(counts[1])
# Out:
# 743031975

# %%
counts
# Out:
# (matrix([[-0.88279573, -0.87689072, -0.87543078, ...,  0.98587739,
#            0.98638712,  0.98646871]]), array([0, 0, 0, ..., 1, 1, 1]))

# %%
high = counts[0][-4900:]

# %%
for index in range(len(high)):
    val = high[index]
    if val >= 0.99:
        print(index+4900)
        break
# Out:
# 4975

# %%
sum(counts[1][(-4900+75):])
# Out:
# 2160824
