# %%
#%%appyter init
from appyter import magic
magic.init(lambda _=globals: _())
# Out:
# /Users/christineyoon/Downloads/RNA-level-functional-predictions/appyter

# %%
# %%appyter markdown
#
# # {{ StringField(
#     name='title',
#     label='Title',
#     default='My title',
# ) }}
#
# {{ TextField(
#     name='description',
#     label='Description',
#     default='My description',
# ) }}
# Out:
# # 'My title'
#
# '''My description'''

# %%
# %%appyter code_eval
# {% set dataset = ChoiceField(
#     name='dataset',
#     label='Dataset',
#     choices={
#         'TCGA': 'tcga.hdf5',
#     },
#     default='MGI',
# ) %}
# {% set gslib = ChoiceField(
#     name='gslib',
#     label='Select a gene set library',
#     choices={
#         'MGI': 'MGI_Mammalian_Phenotype_Level_4_2019.txt',
#     },
#     default='MGI',
# ) %}
# {% set genes = ChoiceField(
#     name='gene',
#     label='Select gene',
#     choices={
#         'gene1': 'gene1',
#     },
#     default='gene',
# ) %}

# %% [markdown]
# # Making predictions
#
# ![Screen%20Shot%202020-06-26%20at%205.51.05%20PM.png](attachment:Screen%20Shot%202020-06-26%20at%205.51.05%20PM.png)
#
# Fig. 1: Calculating the new gene set library. Source: [Geneshot paper](https://academic.oup.com/nar/article/47/W1/W571/5494749).
#
# In this section, we make predictions based on the above formula (Fig. 1). G is the TCGA gene-gene correlation matrix and GF is the chosen gene set library, which is a matrix of genes and phenotypes having mean correlations of a given gene to every other gene in a given set. The goal is to be able to get the new gene set library GF' to make predictions about the TCGA dataset.
# <!-- <img src="attachment:Screen%20Shot%202020-06-26%20at%205.51.05%20PM.png" width="500" height="500"> -->
